# %%
# importing libraries
import pandas as pd      # This imports the pandas library and gives it an alias 'pd'.
                         # Pandas is used for working with tabular data (like spreadsheets).
                         # It helps create, manipulate, and analyze data using data structures like DataFrames.

import requests           # This imports the 'requests' library which allows your code to make HTTP requests.
                         # You’ll use this to connect to web APIs (in this case, YouTube’s API) and get data from the internet.

import time               # This imports Python’s built-in 'time' module.
                         # It allows you to pause or delay the execution of your code.
                         # Useful when you want to avoid overwhelming the API by sending too many requests too quickly (called “rate limiting”).

# %%
API_KEY = "AIzaSyBTzRCR3fUIe4ktLg2qgvh87K4YeAEAd10"  # Your personal YouTube Data API key used to authenticate requests
CHANEL_ID = "UCIvFU5ctIISwVQzsXE7__lw"              # The unique ID of the YouTube channel you want to get videos from

# %%
# Import the requests library to make HTTP requests
import requests

# Define the YouTube Data API endpoint with a valid video ID, your API key, and the resource parts to retrieve.
# This URL requests details (snippet, contentDetails, statistics, and status) about a specific video.
url2 = "https://www.googleapis.com/youtube/v3/videos?id=7lCDEYXw3mM&key=AIzaSyBTzRCR3fUIe4ktLg2qgvh87K4YeAEAd10&part=snippet,contentDetails,statistics,status"

# Send a GET request to the YouTube Data API using the requests library and convert the response to JSON format
response2 = requests.get(url2).json()

# Output the response JSON dictionary.
# This will contain metadata about the video, such as its title, description, statistics (likes, views, etc.), and status (e.g., privacy).
response2
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '3tDM2xV6lz9mAb8XQ5_zHz-qwuQ',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'b2AORplljKfrCg1yfK5lLrw74qE',
#    'id': '7lCDEYXw3mM',
#    'snippet': {'publishedAt': '2012-06-20T23:12:38Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Google I/O 101: Q&A On Using Google APIs',
#     'description': 'Antonio Fuentes speaks to us and takes questions on working with Google APIs and OAuth 2.0.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7lCDEYXw3mM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7lCDEYXw3mM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7lCDEYXw3mM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Google for Developers',
#     'tags': ['api', 'gdl', 'i-o'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Google I/O 101: Q&A On Using Google APIs',
#      'description': 'Antonio Fuentes speaks to us and takes questions on working with Google APIs and OAuth 2.0.'}},
#    'contentDetails': {'duration': 'PT15M51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False},
#    'statistics': {'viewCount': '13954',
#     'likeCount': '88',
#     'favoriteCount': '0',
#     'commentCount': '11'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
# making api call
pageToken = ""  # Empty string for pageToken (used for pagination if there are many videos); can be updated to get the next page of results

url = "https://www.googleapis.com/youtube/v3/search?key=" + API_KEY + \
      "&channelId=" + CHANEL_ID + \
      "&part=snippet,id&order=date&maxResults=10000" + pageToken
      # This constructs the full URL to call the YouTube API 'search' endpoint
      # key=API_KEY: authenticates you
      # channelId=CHANEL_ID: specifies which channel you're pulling videos from
      # part=snippet,id: asks for metadata (title, date, etc.) and video ID
      # order=date: fetches videos sorted by newest first
      # maxResults=10000: sets the max number of results (should be ≤50, 10000 is invalid and will be ignored by the API)
      # + pageToken: appends the pagination token if you're requesting next pages (currently blank)

response = requests.get(url).json()  # Sends an HTTP GET request to the URL, receives the API response, and parses it to a Python dictionary (JSON)

response  # Shows the entire JSON response, which contains video details like title, ID, and date
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 
13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iFayGQr1h8PXKZzP_lT1inQpj9I',
#    'id': {'kind': 'youtube#video', 'videoId': 'gHpJruAb0Yc'},
#    'snippet': {'publishedAt': '2024-06-17T12:24:44Z',
#     'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#     'title': '#kills #drill #uk07rider',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gHpJruAb0Yc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gHpJruAb0Yc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gHpJruAb0Yc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'KESTER  DM ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-17T12:24:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 's-lLHHAS6gr4OEmHxGTpuhb1TtE',
#    'id': {'kind': 'youtube#video', 'videoId': 'LFwSHXW4SbY'},
#    'snippet': {'publishedAt': '2024-05-27T08:28:06Z',
#     'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#     'title': '#nintendo #nickiminaj #ukdrill #music',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LFwSHXW4SbY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LFwSHXW4SbY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LFwSHXW4SbY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'KESTER  DM ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-27T08:28:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qZ7K0KQyWSJ_Ey2_RZiJOhNzEl8',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCIvFU5ctIISwVQzsXE7__lw'},
#    'snippet': {'publishedAt': '2024-02-19T08:11:45Z',
#     'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#     'title': 'KESTER  DM ',
#     'description': 'TRAPSOUL music production based on any trending music Follow on Instagram @its.kester.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'KESTER  DM ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-02-19T08:11:45Z'}}]}

# %%
response['items']  # Accesses the list of videos and other items returned by the API; each item contains details like title, video ID, and publish date
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'kYz8C5Cv4YoXv6REV5vV71KdUMk',
#   'id': {'kind': 'youtube#video', 'videoId': 'SrR5koz0-40'},
#   'snippet': {'publishedAt': '2025-04-05T03:47:21Z',
#    'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#    'title': 'All the best kevin de bruyne #footballedits#trendingshorts #fyp',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'KESTER  DM ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2025-04-05T03:47:21Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Y6I2GvWFSNk1OtsRUjfBt0J4K0s',
#   'id': {'kind': 'youtube#video', 'videoId': 'xn_Z-6vPnMg'},
#   'snippet': {'publishedAt': '2025-01-23T17:52:31Z',
#    'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#    'title': 'Try this changes  on youtube channel  2025 for beginners',
#    'description': "This video is based on teaching people on what settings to change when starting a youtube channel 2025 enjoy and don't forget ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xn_Z-6vPnMg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xn_Z-6vPnMg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xn_Z-6vPnMg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'KESTER  DM ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2025-01-23T17:52:31Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '3ZzWbowQY30fy_ru1OVwiGmVFeU',
#   'id': {'kind': 'youtube#video', 'videoId': 'x7uqNc5kxLM'},
#   'snippet': {'publishedAt': '2025-01-21T04:17:57Z',
#    'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#    'title': 'Absolutely true  #motivation #selfimprovement #consistency #hardwork',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x7uqNc5kxLM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/x7uqNc5kxLM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/x7uqNc5kxLM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'KESTER  DM ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2025-01-21T04:17:57Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'RrAjMVn4RHUxFEW4aoMfWsZi9Hk',
#   'id': {'kind': 'youtube#video', 'videoId': 'HA6WCOQzv2Y'},
#   'snippet': {'publishedAt': '2025-01-19T04:51:30Z',
#    'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#    'title': 'Lamine  yamal. #footballedits #footballshorts #footballhighlights',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/
thumbnails': {'default': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s88-c-k-c0xffffffff-no-rj-mo'},
#     'medium': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s240-c-k-c0xffffffff-no-rj-mo'},
#     'high': {'url': 'https://yt3.ggpht.com/bzQyKzKEkkBP0nlU9_81geIs67fOyOZ4FtNKkYT8RVB3kglXUyp1kjSPA8MuB-LCXzTh0Ydh=s800-c-k-c0xffffffff-no-rj-mo'}},
#    'channelTitle': 'KESTER  DM ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-02-19T08:11:45Z'}}]

# %%
response['items'][0]  # Retrieves the first item (i.e., the most recent video or content) in the list of returned search results
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'kYz8C5Cv4YoXv6REV5vV71KdUMk',
#  'id': {'kind': 'youtube#video', 'videoId': 'SrR5koz0-40'},
#  'snippet': {'publishedAt': '2025-04-05T03:47:21Z',
#   'channelId': 'UCIvFU5ctIISwVQzsXE7__lw',
#   'title': 'All the best kevin de bruyne #footballedits#trendingshorts #fyp',
#   'description': '',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SrR5koz0-40/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'KESTER  DM ',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2025-04-05T03:47:21Z'}}

# %%
video_id = response['items'][0]['id']['videoId']  # Extracts the 'videoId' from the 'id' section of the first video item in the API response
video_id  # Displays the extracted video ID (a unique string that identifies the video on YouTube)
# Out:
# 'SrR5koz0-40'

# %%
video_title = response['items'][0]['snippet']['title']  # Extracts the title of the first video from the 'snippet' section
video_title  # Displays the video title (usually a string like the name of the video on YouTube)
# Out:
# 'All the best kevin de bruyne #footballedits#trendingshorts #fyp'

# %%
upload_date = response['items'][0]['snippet']['publishedAt']  # Gets the full publish date and time of the first video (in ISO 8601 format, e.g., '2024-05-09T15:00:00Z')
upload_date = str(upload_date).split("T")[0]  # Converts the datetime string to just the date by splitting at 'T' and keeping the first part (e.g., '2024-05-09')
upload_date  # Displays the cleaned upload date as a string in 'YYYY-MM-DD' format
# Out:
# '2025-04-05'

# %%
def get_video_details(video_id):  # Define a function that takes a video_id and returns its stats

    # second API call to get video statistics (views, likes, comments)
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id=" + video_id + "&part=statistics&key=" + API_KEY
    # Construct the URL to fetch statistics for a single video using its video ID and API key

    response_video_stats = requests.get(url_video_stats).json()
    # Send the HTTP GET request to the API and convert the response into a JSON format (dictionary)

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    # Extract the number of views for the video

    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    # Extract the number of likes for the video

    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    # Extract the number of comments for the video

    return view_count, like_count, comment_count  # Return the three stats as a tuple

# %%
def get_videos(df):  # Define a function that takes an existing DataFrame and adds video data to it

    # making API call
    pageToken = ""  # Page token is used for pagination; currently empty so it fetches the first page
    url = "https://www.googleapis.com/youtube/v3/search?key=" + API_KEY + "&channelId=" + CHANEL_ID + "&part=snippet,id&order=date&maxResults=50" + pageToken
    # Construct the API URL to fetch video metadata from a specific channel (latest 50 videos)

    response = requests.get(url).json()  # Send GET request and convert the response to a JSON object (dictionary)

    time.sleep(1)  # Pause for 1 second to avoid hitting API rate limits

    for video in response['items']:  # Loop through each item (video or playlist or other) in the response
        if video['id']['kind'] == 'youtube#video':  # Ensure we're only processing actual videos (not playlists or channels)

            video_id = video['id']['videoId']  # Extract the unique ID of the video
            video_title = video['snippet']['title']  # Get the title of the video
            upload_date = video['snippet']['publishedAt']  # Get the full date-time the video was published
            upload_date = str(upload_date).split("T")[0]  # Extract just the date (YYYY-MM-DD)

            view_count, like_count, comment_count = get_video_details(video_id)
            # Call a separate function to get video statistics: views, likes, comments

            df = pd.concat([df, pd.DataFrame([{
                'video_id': video_id,  # Add video ID to the new row
                'video_title': video_title,  # Add title
                'upload_date': upload_date,  # Add upload date
                'view_count': view_count,  # Add view count
                'like_count': like_count,  # Add like count
                'comment_count': comment_count  # Add comment count
            }])], ignore_index=True)  # Append the new row to the DataFrame

    return df  # Return the updated DataFrame with all video info

# %%
# saving in pandas dataframe
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "comment_count"])
# Create an empty DataFrame with specific column names to hold video data

df = get_videos(df)
# Call the get_videos function you defined earlier
# It will fill the DataFrame by fetching video metadata and statistics using the YouTube API

df
# Display the filled DataFrame (shows all collected video information)
# Out:
#        video_id                                        video_title  \
# 0   SrR5koz0-40  All the best kevin de bruyne #footballedits#tr...
# 1   xn_Z-6vPnMg  Try this changes  on youtube channel  2025 for...
# 2   x7uqNc5kxLM  Absolutely true  #motivation #selfimprovement ...
# 3   HA6WCOQzv2Y  Lamine  yamal. #footballedits #footballshorts ...
# 4   qVQ4EhtxxGY  Unbelievable  performance   #footballhighlight...
# 5   42o-NPOAg2g  After  destroying  Newcastle 🤣    #football #f...
# 6   wuOluzRAcK4                            Vini is back  #football
# 7   Wx39QENE__o  Rodriguez skills #football #footballhighlights...
# 8   zferxFeEDxU  That&#39;s why he is the nest 🪹 #football #for...
# 9   am0eNjvUo20  Don&#39;t go for looks ☺️ #lovesong #fyp #cons...
# 10  a7A25xxiKgs  Don&#39;t quite #selfimprovement  #mindset #co...
# 11  0mFK-pflqBo  God say the worse thing you can do is......#se...
# 12  83Gd3KTq2bk          Anime from old country  #anime #animeedit
# 13  cq4tvQ9iMvU                      #anime #animeedit #animedance
# 14  R80Okukvg_c  Always choose your peace at all cost  #happy #...
# 15  OlbaaS2jwIk    Just be humble 🙏..... #shorts #lovestatus #love
# 16  DehbU9sj4lE                                           #lilmabu
# 17  KQJnVHfeV6I             #kills #uk07rider #drill #rap #podcast
# 18  gHpJruAb0Yc                           #kills #drill #uk07rider
# 19  LFwSHXW4SbY              #nintendo #nickiminaj #ukdrill #music
#
#    upload_date view_count like_count comment_count
# 0   2025-04-05        110          3             0
# 1   2025-01-23          5          0             0
# 2   2025-01-21         16          2             0
# 3   2025-01-19         23          1             0
# 4   2025-01-18        149          6             0
# 5   2025-01-18        565         16             0
# 6   2025-01-18        127          4             0
# 7   2025-01-17        104          2             0
# 8   2025-01-17        681         10             1
# 9   2024-12-19        353          8             0
# 10  2024-12-19        543         33             0
# 11  2024-12-04        741         81             0
# 12  2024-11-13          4          0             0
# 13  2024-11-13          5          1             0
# 14  2024-09-16         15          2             0
# 15  2024-09-15        536          4             0
# 16  2024-06-28         22          4             0
# 17  2024-06-18         14          6             0
# 18  2024-06-17        211         11             3
# 19  2024-05-27         16          2             0
